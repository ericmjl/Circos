# %%
import networkx as nx 
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = nx.read_gpickle('test_graphs/07 inter-subtype interactions.pkl')

# %%
G.nodes()
# Out:
# ['H10N8',
#  'H10N9',
#  'H10N1',
#  'H10N2',
#  'H10N3',
#  'H10N4',
#  'H10N5',
#  'H10N6',
#  'H10N7',
#  'H1N8',
#  'H2N4',
#  'H2N5',
#  'H2N6',
#  'H2N7',
#  'H2N1',
#  'H2N2',
#  'H2N3',
#  'H2N8',
#  'H2N9',
#  'H8N8',
#  'H1N2',
#  'H8N4',
#  'H8N2',
#  'H8N1',
#  'H7N2',
#  'H9N6',
#  'Mixed',
#  'H4N2',
#  'H4N3',
#  'H4N1',
#  'H5N3',
#  'H11N7',
#  'H4N7',
#  'H3N9',
#  'H3N8',
#  'H12N9',
#  'H4N4',
#  'H3N1',
#  'H3N3',
#  'H3N2',
#  'H3N5',
#  'H3N7',
#  'H3N6',
#  'H4N8',
#  'H4N9',
#  'H5N9',
#  'H5N8',
#  'H5N7',
#  'H5N6',
#  'H5N5',
#  'H5N4',
#  'H4N6',
#  'H5N2',
#  'H5N1',
#  'H4N5',
#  'H6N8',
#  'H6N9',
#  'H7N9',
#  'H7N8',
#  'H7N5',
#  'H7N4',
#  'H6N2',
#  'H7N6',
#  'H7N1',
#  'H6N5',
#  'H6N6',
#  'H6N7',
#  'H11N9',
#  'H11N8',
#  'H6N1',
#  'H7N7',
#  'H1N9',
#  'H6N3',
#  'H1N3',
#  'H6N4',
#  'H1N1',
#  'H1N7',
#  'H1N6',
#  'H1N5',
#  'H1N4',
#  'H9N3',
#  'H9N2',
#  'H9N1',
#  'H9N7',
#  'H7N3',
#  'H9N5',
#  'H9N9',
#  'H9N8',
#  'H12N8',
#  'H11N6',
#  'H11N1',
#  'H11N3',
#  'H11N2',
#  'H12N2',
#  'H12N3',
#  'H12N1',
#  'H12N6',
#  'H12N7',
#  'H12N4',
#  'H12N5',
#  'H16N3',
#  'H15N9',
#  'H14N6',
#  'H15N4',
#  'H14N2',
#  'H13N6',
#  'H13N2',
#  'H13N9',
#  'H13N8']

# %%
from circos import CircosPlot

# %%
nodes = G.nodes()
edges = [(u, v) for u, v in G.edges() if 'H3N2' in [u, v] and u != v]

c = CircosPlot(nodes, edges, 10, 'blue')
c.draw()
